# %%
from requests import post
import pandas as pd

# %%
total_games = post('https://api.igdb.com/v4/games/count', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer gd8cqh6pc7bssjvsbo7bnqtqujvtop'},'data': 'where rating > 0;'})
print ("response: %s" % str(total_games.json()))
# Out:
# response: {'count': 29227}

# %%
import time
import random
game_list = []
random.seed(42)
for i in random.sample(range(10000), 50): 
    games = post('https://api.igdb.com/v4/games', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer gd8cqh6pc7bssjvsbo7bnqtqujvtop'},
                                                    'data': f'fields *; where id = {i};'})
    game_list.append(games.json()[0])
    time.sleep(1)

# %%
df = pd.DataFrame(game_list)
df.head(30)
# Out:
#       id                                       age_ratings  aggregated_rating  \
# 0   1824                                           [65400]          80.000000
# 1    409                                             [266]          90.000000
# 2   4506                                            [2318]                NaN
# 3   4012                                           [79499]          30.000000
# 4   3657                                               NaN                NaN
# 5   2286                       [5161, 32670, 48905, 95998]          87.400000
# 6   1679                                            [6038]          70.000000
# 7   8935                            [6165, 123226, 151391]          77.500000
# 8   1424                                             [492]                NaN
# 9   9674                                    [48845, 71971]          62.500000
# 10  6912                                     [3946, 76114]          46.000000
# ...

# %%
import warnings
game_list = []
random.seed(30)
for i in random.sample(range(10000), 5000): 
    games = post('https://api.igdb.com/v4/games', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer gd8cqh6pc7bssjvsbo7bnqtqujvtop'},'data': f'fields *; where id = {i};'})
    temp_df = pd.DataFrame(games.json())
    df = df.append(temp_df, ignore_index=True)
    time.sleep(1)
    pd.options.mode.chained_assignment = None
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2z/frb2n0xx0xbfzmbmnjvfppjh0000gn/T/ipykernel_36368/1809680596.py in <module>
#       4 for i in random.sample(range(10000), 5000):
#       5     games = post('https://api.igdb.com/v4/games', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer gd8cqh6pc7bssjvsbo7bnqtqujvtop'},'data': f'fields *; where id = {i};'})
# ----> 6     temp_df = pd.DataFrame(games.json())
#       7     df = df.append(temp_df, ignore_index=True)
#       8     time.sleep(1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# ...

# %%
df
# Out:
#        id                               age_ratings  aggregated_rating  \
# 0    1824                                   [65400]               80.0
# 1     409                                     [266]               90.0
# 2    4506                                    [2318]                NaN
# 3    4012                                   [79499]               30.0
# 4    3657                                       NaN                NaN
# ..    ...                                       ...                ...
# 636   335                             [5639, 44406]               80.0
# 637  3093                                   [84644]               70.0
# 638  1958  [326, 36397, 81188, 87199, 87200, 87201]               45.0
# 639  5482                                   [70030]               30.0
# 640   535                                    [3869]               80.2
#
#      aggregated_rating_count                              alternative_names  \
# ...

# %%
#Import packages 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       1 non-null      int64
#  1   age_ratings              1 non-null      object
#  2   aggregated_rating        1 non-null      float64
#  3   aggregated_rating_count  1 non-null      int64
#  4   alternative_names        1 non-null      object
#  5   category                 1 non-null      int64
#  6   collection               1 non-null      int64
#  7   cover                    1 non-null      int64
#  8   created_at               1 non-null      int64
#  9   external_games           1 non-null      object
#  10  first_release_date       1 non-null      int64
#  11  follows                  1 non-null      int64
#  12  franchises               1 non-null      object
#  13  game_engines             1 non-null      object
# ...

# %%
df.shape
# Out:
# (1, 40)

# %%
#Checking for missing values 
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis= 1)
missing.columns=["count", "%" ]
missing.sort_values(by=['count', '%'], ascending=False)
# Out:
#                          count    %
# id                           0  0.0
# age_ratings                  0  0.0
# aggregated_rating            0  0.0
# aggregated_rating_count      0  0.0
# alternative_names            0  0.0
# artworks                     0  0.0
# category                     0  0.0
# collection                   0  0.0
# cover                        0  0.0
# created_at                   0  0.0
# external_games               0  0.0
# first_release_date           0  0.0
# follows                      0  0.0
# game_engines                 0  0.0
# game_modes                   0  0.0
# genres                       0  0.0
# involved_companies           0  0.0
# keywords                     0  0.0
# multiplayer_modes            0  0.0
# name                         0  0.0
# platforms                    0  0.0
# player_perspectives          0  0.0
# rating                       0  0.0
# rating_count                 0  0.0
# release_dates                0  0.0
# ...

# %%
df['name'].value_counts()
# Out:
# Need for Speed: Carbon    1
# Name: name, dtype: int64

# %%
IGDB_df[[ 'total_rating_count', 'rating_count', 'follows']].gsub("\\.[0-9]*$", "", z)

# %%
IGDB_df[[ 'total_rating_count', 'rating_count', 'follows']] = IGDB_df[[ 'total_rating_count', 'rating_count', 'follows']].astype(int)

# %%
from requests import post
response = post('https://api.igdb.com/v4/platforms', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer gd8cqh6pc7bssjvsbo7bnqtqujvtop'},'data': 'fields abbreviation,alternative_name,category,checksum,created_at,generation,name,platform_family,platform_logo,slug,summary,updated_at,url,versions,websites; limit 500;'})
print ("response: %s" % str(response.json()))
# Out:
# response: [{'id': 158, 'alternative_name': 'Commodore Dynamic Total Vision', 'category': 6, 'created_at': 1510012800, 'name': 'Commodore CDTV', 'platform_logo': 292, 'slug': 'commodore-cdtv', 'updated_at': 1522972800, 'url': 'https://www.igdb.com/platforms/commodore-cdtv', 'versions': [223], 'websites': [26], 'checksum': '5d48648e-283c-e2df-df7d-6d3cbc7e0a58'}, {'id': 339, 'alternative_name': 'Kids Computer Pico', 'category': 1, 'created_at': 1595808000, 'generation': 4, 'name': 'Sega Pico', 'platform_family': 3, 'slug': 'sega-pico', 'updated_at': 1595808000, 'url': 'https://www.igdb.com/platforms/sega-pico', 'versions': [456], 'checksum': '6e867a5b-a071-fc7b-945b-a0622f64a4bc'}, {'id': 8, 'abbreviation': 'PS2', 'alternative_name': 'PS2', 'category': 1, 'created_at': 1297555200, 'generation': 6, 'name': 'PlayStation 2', 'platform_logo': 254, 'platform_family': 1, 'slug': 'ps2', 'updated_at': 1414972800, 'url': 'https://www.igdb.com/platforms/ps2', 'versions': [58, 114], 'checksum': '
# ...

# %%
import pandas as pd
df = pd.DataFrame(response.json())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                200 non-null    int64
#  1   alternative_name  102 non-null    object
#  2   category          190 non-null    float64
#  3   created_at        200 non-null    int64
#  4   name              200 non-null    object
#  5   platform_logo     147 non-null    float64
#  6   slug              200 non-null    object
#  7   updated_at        200 non-null    int64
#  8   url               200 non-null    object
#  9   versions          200 non-null    object
#  10  websites          93 non-null     object
#  11  checksum          200 non-null    object
#  12  generation        92 non-null     float64
#  13  platform_family   49 non-null     float64
#  14  abbreviation      107 non-null    object
#  15  summary           7 non-null      object
# ...

# %%
df
# Out:
#       id                alternative_name  category  created_at  \
# 0    158  Commodore Dynamic Total Vision       6.0  1510012800
# 1    339              Kids Computer Pico       1.0  1595808000
# 2      8                             PS2       1.0  1297555200
# 3     39                             NaN       4.0  1317686400
# 4     94                             NaN       6.0  1414195200
# ..   ...                             ...       ...         ...
# 195  386                         Quest 2       1.0  1632258796
# 196  390                           PSVR2       1.0  1641416080
# 197  165                            PSVR       1.0  1518705184
# 198   47                             NaN       3.0  1326279244
# 199  471                             NaN       1.0  1685641825
#
#                  name  platform_logo            slug  updated_at  \
# 0      Commodore CDTV          292.0  commodore-cdtv  1522972800
# 1           Sega Pico            NaN       sega-pico  1595808000
# ...

# %%
df[['name', 'id']].nunique()
# Out:
# name    200
# id      200
# dtype: int64

# %%
df[['category']].nunique()
# Out:
# category    6
# dtype: int64

# %%
df['category'].value_counts()
# Out:
# 1.0    80
# 6.0    55
# 5.0    34
# 4.0    10
# 3.0     8
# 2.0     3
# Name: category, dtype: int64

# %%
df[df['id'] == 6]
# Out:
#    id alternative_name  category  created_at                    name  \
# 9   6            mswin       4.0  1297555200  PC (Microsoft Windows)
#
#    platform_logo slug  updated_at                                 url  \
# 9          203.0  win  1470009600  https://www.igdb.com/platforms/win
#
#                versions websites                              checksum  \
# 9  [1, 13, 14, 15, 124]      [2]  5aae54d0-390e-a4ec-a9ee-4ad4cc346992
#
#    generation  platform_family abbreviation summary
# 9         NaN              NaN           PC     NaN

# %%
df.to_csv('platforms_info.csv')

# %%
IGBD['is_pc']=IGDB['platforms'].map(lambda x: '6' in x if pd.notnull(x) else np.nan).astype(float)

# %%
IGDB['platforms'].map(lambda x: len(set(platforms_info[platforms_info['category'] == 4.0]['id'].tolist()).intersection(set(x)))>0 if pd.notnull(x) else np.nan).astype(float).value_counts()

# %%
import numpy as np 

df['generation'] = np.round(df['generation'], decimals=0)

# %%
df.generation
# Out:
# 0      NaN
# 1      4.0
# 2      6.0
# 3      NaN
# 4      NaN
#       ...
# 195    NaN
# 196    9.0
# 197    8.0
# 198    NaN
# 199    9.0
# Name: generation, Length: 200, dtype: float64

# %%
from requests import post
response = post('https://api.igdb.com/v4/games/', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer gd8cqh6pc7bssjvsbo7bnqtqujvtop'},'data': 'search "Crash Bandicoot"; fields name,release_date.human;'})
print ("response: %s" % str(response.json()))
# Out:
# response: [{'title': 'Invalid Field', 'status': 400, 'cause': "Invalid field name: 'release_date.human'"}]

# %%
import pandas as pd
game_1341= pd.DataFrame(response.json())

# %%
game_1341
# Out:
#        id  category  created_at        date  game         human   m  platform  \
# 0   25272         0  1421046095  1068508800  1341  Nov 11, 2003  11         8
# 1  137722         0  1517582570  1068595200  1341  Nov 12, 2003  11        21
# 2   25280         2  1421046095  1072828800  1341          2003  12        21
# 3   25274         0  1421046095  1069200000  1341  Nov 19, 2003  11         6
# 4   25275         0  1421046095  1070582400  1341  Dec 05, 2003  12         6
# 5   25281         0  1421046095  1210636800  1341  May 13, 2008   5         6
# 6  137723         0  1517582570  1068595200  1341  Nov 12, 2003  11        21
# 7   25279         0  1421046095  1077840000  1341  Feb 27, 2004   2        21
# 8   25277         0  1421046095  1077840000  1341  Feb 27, 2004   2        11
# 9   25276         0  1421046095  1070323200  1341  Dec 02, 2003  12        11
#
#    region  updated_at     y                              checksum
# ...

# %%
from requests import post
response = post('https://api.igdb.com/v4/genres', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer gd8cqh6pc7bssjvsbo7bnqtqujvtop'},'data': 'fields checksum,created_at,name,slug,updated_at,url; limit 500;'})
print ("response: %s" % str(response.json()))
# Out:
# response: [{'id': 4, 'created_at': 1297555200, 'name': 'Fighting', 'slug': 'fighting', 'updated_at': 1323216000, 'url': 'https://www.igdb.com/genres/fighting', 'checksum': '2ccc6572-bdde-6ed4-8843-25447ea40782'}, {'id': 5, 'created_at': 1297555200, 'name': 'Shooter', 'slug': 'shooter', 'updated_at': 1323216000, 'url': 'https://www.igdb.com/genres/shooter', 'checksum': 'bb15fd3f-0f46-e5f3-2b40-d046cf9bd2ef'}, {'id': 7, 'created_at': 1297555200, 'name': 'Music', 'slug': 'music', 'updated_at': 1323216000, 'url': 'https://www.igdb.com/genres/music', 'checksum': '22d44a0d-89c7-580f-eef2-e06f178fdd47'}, {'id': 8, 'created_at': 1297555200, 'name': 'Platform', 'slug': 'platform', 'updated_at': 1323216000, 'url': 'https://www.igdb.com/genres/platform', 'checksum': '697fc5a4-b96f-a803-288a-498bd5dd1de1'}, {'id': 9, 'created_at': 1297555200, 'name': 'Puzzle', 'slug': 'puzzle', 'updated_at': 1323216000, 'url': 'https://www.igdb.com/genres/puzzle', 'checksum': '616de9c3-8a00-0232-9df9-00014cfac51
# ...

# %%
import pandas as pd
df = pd.DataFrame(response.json())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          23 non-null     int64
#  1   created_at  23 non-null     int64
#  2   name        23 non-null     object
#  3   slug        23 non-null     object
#  4   updated_at  23 non-null     int64
#  5   url         23 non-null     object
#  6   checksum    23 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 1.4+ KB

# %%
df[['name', 'id']]
# Out:
#                           name  id
# 0                     Fighting   4
# 1                      Shooter   5
# 2                        Music   7
# 3                     Platform   8
# 4                       Puzzle   9
# 5                       Racing  10
# 6     Real Time Strategy (RTS)  11
# 7           Role-playing (RPG)  12
# 8                    Simulator  13
# 9                        Sport  14
# 10                    Strategy  15
# 11   Turn-based strategy (TBS)  16
# 12                    Tactical  24
# 13                 Quiz/Trivia  26
# 14  Hack and slash/Beat 'em up  25
# 15                     Pinball  30
# 16                   Adventure  31
# 17                      Arcade  33
# 18                Visual Novel  34
# 19                       Indie  32
# 20           Card & Board Game  35
# 21                        MOBA  36
# 22             Point-and-click   2

# %%
df.to_csv('genres_info.csv')
